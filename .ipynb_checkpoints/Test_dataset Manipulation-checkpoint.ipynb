# %%
import pandas as pd
import os
import shutil
import numpy as np

# %% [markdown]
# ### Renaming

# %%
parent_folder = "/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21_test/cartoon_set_test/img"
os.chdir(parent_folder)
files = os.listdir(parent_folder)
length_train_val = 10000 # starting points

for index, file in enumerate(files):
    os.rename(os.path.join(parent_folder, file), os.path.join(parent_folder, ''.join([str(index+length_train_val), '.png'])))

# %%
parent_folder = "/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21_test/celeba_test/img"
os.chdir(parent_folder)
files = os.listdir(parent_folder)
length_train_val = 5000

for index, file in enumerate(files):
    os.rename(os.path.join(parent_folder, file), os.path.join(parent_folder, ''.join([str(index+length_train_val), '.jpg'])))

# %% [markdown]
# ### Moving folder to folder

# %%
source = "/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21_test/cartoon_set_test/img/"
dest = "/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21/cartoon_set/img/"
files = os.listdir(source)
for f in files:
    if os.path.splitext(f)[1] in (".jpg", ".gif", ".png"):
        shutil.move(source + f, dest)

# %%
source = "/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21_test/celeba_test/img/"
dest = "/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21/celeba/img/"
files = os.listdir(source)
for f in files:
    if os.path.splitext(f)[1] in (".jpg", ".gif", ".png"):
        shutil.move(source + f, dest)

# %%
new_img_names=[]
for i in range(5000, 6000):
    new_img_names.append(str(i) + ".jpg")

# %%
new_img_names
# Out:
# ['5000.jpg',
#  '5001.jpg',
#  '5002.jpg',
#  '5003.jpg',
#  '5004.jpg',
#  '5005.jpg',
#  '5006.jpg',
#  '5007.jpg',
#  '5008.jpg',
#  '5009.jpg',
#  '5010.jpg',
#  '5011.jpg',
#  '5012.jpg',
#  '5013.jpg',
#  '5014.jpg',
#  '5015.jpg',
#  '5016.jpg',
#  '5017.jpg',
#  '5018.jpg',
#  '5019.jpg',
#  '5020.jpg',
#  '5021.jpg',
#  '5022.jpg',
#  '5023.jpg',
#  '5024.jpg',
#  '5025.jpg',
#  '5026.jpg',
#  '5027.jpg',
#  '5028.jpg',
#  '5029.jpg',
#  '5030.jpg',
#  '5031.jpg',
#  '5032.jpg',
#  '5033.jpg',
#  '5034.jpg',
#  '5035.jpg',
#  '5036.jpg',
#  '5037.jpg',
#  '5038.jpg',
#  '5039.jpg',
#  '5040.jpg',
#  '5041.jpg',
#  '5042.jpg',
#  '5043.jpg',
#  '5044.jpg',
#  '5045.jpg',
#  '5046.jpg',
#  '5047.jpg',
#  '5048.jpg',
#  '5049.jpg',
#  '5050.jpg',
#  '5051.jpg',
#  '5052.jpg',
#  '5053.jpg',
#  '5054.jpg',
#  '5055.jpg',
#  '5056.jpg',
#  '5057.jpg',
#  '5058.jpg',
#  '5059.jpg',
#  '5060.jpg',
#  '5061.jpg',
#  '5062.jpg',
#  '5063.jpg',
#  '5064.jpg',
#  '5065.jpg',
# ...

# %%
labels_file_0 = pd.read_csv("/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21_test/celeba_test/labels.csv",  sep="\t", usecols=["img_name", "gender", "smiling"])

# %%
labels_file_1 = pd.read_csv("/Users/macbookpro/UCL - MSc Integrated Machine Learning Systems/Y1/Applied Machine Learning I/Final Assignment/AMLS_20-21_SN17024244/Datasets/dataset_AMLS_20-21/celeba/labels.csv",  sep="\t", usecols=["img_name", "gender", "smiling"])

# %%
labels_file_0["img_name"] = new_img_names

# %%
labels_file_1 = pd.concat([labels_file_1, labels_file_0], ignore_index=True)

# %%
labels_file_1
# Out:
#       img_name  gender  smiling
# 0        0.jpg      -1        1
# 1        1.jpg      -1        1
# 2        2.jpg       1       -1
# 3        3.jpg      -1       -1
# 4        4.jpg      -1       -1
# ...        ...     ...      ...
# 5995  5995.jpg       1        1
# 5996  5996.jpg       1        1
# 5997  5997.jpg       1        1
# 5998  5998.jpg       1        1
# 5999  5999.jpg       1        1
#
# [6000 rows x 3 columns]

# %%
file_name="5999.jpg"
extension = "jpg"
str(int(os.path.splitext(file_name)[0]) + 5000) + "." + extension
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-2e2cb5980af0> in <module>
#       1 file_name="5999.jpg"
# ----> 2 str(int(os.path.splitext(file_name)[0]) + 5000) + "." + extension
#
# NameError: name 'extension' is not defined
